# %%
# %matplotlib notebook

# %%
import json
import requests
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from scipy import stats
import scipy

api_key = "51633da5ab8c54ec05396a059e8dc4a6"

# %%
url = "http://api.eia.gov/series/?"

query_url = f"{url}api_key=51633da5ab8c54ec05396a059e8dc4a6&series_id=SEDS.PAACD.CA.A"

# %%
oil_data = requests.get(query_url).json()
oil_data

oil_price = pd.read_csv("oil_price.csv")

# %%
df = oil_data['series'][0]['data']

oil_price
# Out:
#     Year  Price  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   2017  20.85         NaN         NaN         NaN         NaN         NaN
# 1   2016  18.50         NaN         NaN         NaN         NaN         NaN
# 2   2015  21.75         NaN         NaN         NaN         NaN         NaN
# 3   2014  27.83         NaN         NaN         NaN         NaN         NaN
# 4   2013  28.92         NaN         NaN         NaN         NaN         NaN
# 5   2012  29.92         NaN         NaN         NaN         NaN         NaN
# 6   2011  28.46         NaN         NaN         NaN         NaN         NaN
# 7   2010  22.36         NaN         NaN         NaN         NaN         NaN
# 8   2009  18.20         NaN         NaN         NaN         NaN         NaN
# 9   2008  25.33         NaN         NaN         NaN         NaN         NaN
# 10  2007  20.60         NaN         NaN         NaN         NaN         NaN
# 11  2006  19.16         NaN         NaN         NaN         NaN         NaN
# 12  2005  16.90         NaN         NaN         NaN         NaN         NaN
# 13  2004  14.20         NaN         NaN         NaN         NaN         NaN
# 14  2003  11.77         NaN         NaN         NaN         NaN         NaN
# 15  2002   9.66         NaN         NaN         NaN         NaN         NaN
# 16  2001  10.51         NaN         NaN         NaN         NaN         NaN
# 17  2000  10.89         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8
# 0         2000       10.89
# 1         2001       10.51
# 2         2002        9.66
# 3         2003       11.77
# 4         2004       14.20
# 5         2005       16.90
# 6         2006       19.16
# 7         2007       20.60
# 8         2008       25.33
# 9         2009       18.20
# 10        2010       22.36
# 11        2011       28.46
# 12        2012       29.92
# 13        2013       28.92
# 14        2014       27.83
# 15        2015       21.75
# 16        2016       18.50
# 17        2017       20.85

# %%
df = pd.DataFrame(data=oil_price)



df.rename(columns = {list(df)[0]: 'Year'}, inplace = True)
df.rename(columns = {list(df)[1]: 'Price'}, inplace = True)
df.sort_values("Year", ascending = True, inplace = True) 

df
# Out:
#     Year  Price  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 17  2000  10.89         NaN         NaN         NaN         NaN         NaN
# 16  2001  10.51         NaN         NaN         NaN         NaN         NaN
# 15  2002   9.66         NaN         NaN         NaN         NaN         NaN
# 14  2003  11.77         NaN         NaN         NaN         NaN         NaN
# 13  2004  14.20         NaN         NaN         NaN         NaN         NaN
# 12  2005  16.90         NaN         NaN         NaN         NaN         NaN
# 11  2006  19.16         NaN         NaN         NaN         NaN         NaN
# 10  2007  20.60         NaN         NaN         NaN         NaN         NaN
# 9   2008  25.33         NaN         NaN         NaN         NaN         NaN
# 8   2009  18.20         NaN         NaN         NaN         NaN         NaN
# 7   2010  22.36         NaN         NaN         NaN         NaN         NaN
# 6   2011  28.46         NaN         NaN         NaN         NaN         NaN
# 5   2012  29.92         NaN         NaN         NaN         NaN         NaN
# 4   2013  28.92         NaN         NaN         NaN         NaN         NaN
# 3   2014  27.83         NaN         NaN         NaN         NaN         NaN
# 2   2015  21.75         NaN         NaN         NaN         NaN         NaN
# 1   2016  18.50         NaN         NaN         NaN         NaN         NaN
# 0   2017  20.85         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8
# 17        2017       20.85
# 16        2016       18.50
# 15        2015       21.75
# 14        2014       27.83
# 13        2013       28.92
# 12        2012       29.92
# 11        2011       28.46
# 10        2010       22.36
# 9         2009       18.20
# 8         2008       25.33
# 7         2007       20.60
# 6         2006       19.16
# 5         2005       16.90
# 4         2004       14.20
# 3         2003       11.77
# 2         2002        9.66
# 1         2001       10.51
# 0         2000       10.89

# %%
plt.figure(1)

plt.plot(df['Year'], df["Price"], color="blue", label="Gas prices over time" )
plt.grid(linestyle='--')
plt.ylabel("Gas prices over time")
#plt.yticks(list(np.arange(5,30,5)))

#plt.xticks(np.arange(1970,2010,5), ('1970','1980','1990','2000','2010'))



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
hev_sales = pd.read_csv('hev_sales.csv')
pev_sales = pd.read_csv('pev_sales.csv')

hev_df = pd.DataFrame(data=hev_sales)
pev_df = pd.DataFrame(data=pev_sales)

hev_df.columns
# Out:
# Index(['Year', 'HEV Vehicle Sales '], dtype='object')

# %%
plt.figure(2)

plt.plot(hev_df['Year'], hev_df["HEV Vehicle Sales "], color="blue", label="HEV Sales over time" )
plt.grid(linestyle='--')
plt.ylabel("HEV Sales Over Time")
plt.title("HEV Vehicle Sales Over Time")
#plt.yticks(list(np.arange(5,30,5)))

#plt.xticks(np.arange(1970,2010,5), ('1970','1980','1990','2000','2010'))



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="911.1111352473135">

# %%
plt.figure(2)

plt.plot(pev_df['Year'], pev_df["PEV Sales"], color="blue", label="HEV Sales over time" )
plt.grid(linestyle='--')
plt.ylabel("PEV Sales Over Time")
#plt.yticks(list(np.arange(5,30,5)))

#plt.xticks(np.arange(1970,2010,5), ('1970','1980','1990','2000','2010'))



plt.show()

# %%
#grabbing hev sales over time
year = hev_sales.iloc[:, 0]

hev_sales_per_year = hev_sales.iloc[:, 1]
hev_slope, hev_int, hev_r, hev_p, hev_std_err = stats.linregress(
    year, hev_sales_per_year)
hev_fit = hev_slope * year + hev_int

# %%
#grabbing gas sales over time
year = df.iloc[:, 0]

oil_sales_per_year = df.iloc[:, 1]
oil_slope, oil_int, oil_r, oil_p, oil_std_err = stats.linregress(
    year, oil_sales_per_year)
oil_fit = oil_slope * year + oil_int

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle("HEV and Oil Sales over time", fontsize=16, fontweight="bold")

ax1.set_xlim(min(year), max(year))
ax1.plot(year, hev_sales_per_year, linewidth=1, marker="o")
ax1.plot(year, hev_fit, "b--", linewidth=1)
ax1.set_ylabel("HEV Sales Over Time")

ax2.plot(year, oil_sales_per_year, linewidth=1, marker="o", color="r")
ax2.plot(year, oil_fit, "r--", linewidth=1)
ax2.set_ylabel("Gas Prices Over Time")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# Text(0, 0.5, 'Gas Prices Over Time')

# %%
x = oil_sales_per_year
y = hev_sales_per_year

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x,y)

# %%
p_value
# Out:
# 9.388683723556552e-07
